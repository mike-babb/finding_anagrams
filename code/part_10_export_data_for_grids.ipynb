# %%
# mike babb
# 2025 03 12
# get the definitions of the top 5 word groups by character length

# %%
from collections import Counter
import os
import sqlite3

# %%
import duckdb
import json
from lxml import etree
import pandas as pd
import pprint
import requests

# %%
import _run_constants as rc
from part_00_file_db_utils import query_db, write_data_to_sqlite

# %% [markdown]
# # Libraries

# %%
db_path_name = os.path.join(rc.db_path, rc.db_name)

# %%
cuts = list(range(0, 217001, 1000))

# %%
# the from word id df
sql = 'select word_group_id, word_id from words;'
fw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
fw_df.columns = ['from_word_group_id', 'from_word_id']

# the to word id df
sql = 'select word_group_id, word_id from words;'
tw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
tw_df.columns = ['to_word_group_id', 'to_word_id']

# %%
# counters
to_word_counter = Counter()
from_word_counter = Counter()
for i_c, ii in enumerate(cuts[:-1]):
    print('#### TO WORDS')
    # to words
    sql = f'select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= {ii} and to_word_group_id < {cuts[i_c+ 1]};'
    print(sql)
    wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
    print(wg_df.shape)
    wg_df = pd.merge(left = wg_df, right = fw_df)
    wg_df = pd.merge(left = wg_df, right = tw_df)
    print(wg_df.shape)

    # count - and this is where it gets counter intuitive. The to word groups are counts of from words
    from_word_counter.update(wg_df['to_word_id'])

    print('#### FROM WORDS')
    # from words
    sql = f'select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= {ii} and from_word_group_id < {cuts[i_c+ 1]};'
    print(sql)
    wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
    print(wg_df.shape)
    wg_df = pd.merge(left = wg_df, right = fw_df)
    wg_df = pd.merge(left = wg_df, right = tw_df)
    print(wg_df.shape)

    # aggregate by to word
    to_word_counter.update(wg_df['from_word_id'])

# %%
sql = 'select * from words;'
word_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)

# %%
word_df.head()

# %%
word_df['n_from_words'] = word_df['word_id'].map(from_word_counter)
word_df['n_to_words'] = word_df['word_id'].map(to_word_counter)

# %%
write_data_to_sqlite(df = word_df, table_name='word_counts', db_path=rc.db_path, db_name=rc.db_name)

# %%
# now, let's format for export to json

# %%
word_df.shape

# %%
word_df.head()

# %%
word_df['n_from_rank'] = word_df[['n_chars', 'n_from_words']].groupby(['n_chars']).rank(method = 'first', ascending=False)

# %%
word_df['n_to_rank'] = word_df[['n_chars', 'n_to_words']].groupby(['n_chars']).rank(method = 'first',ascending=False)

# %%
# melt to get the word count
wc_df = pd.melt(frame = word_df, id_vars = ['word_id', 'lcase', 'n_chars'],
                  value_vars = ['n_from_words','n_to_words'],
                  var_name = 'direction', value_name = 'n_words')

# %%
wc_df.shape

# %%
wc_df['direction'].unique().tolist()

# %%
recode_dict = {'n_from_words':'from',
               'n_to_words':'to'}

# %%
wc_df['direction'] = wc_df['direction'].map(recode_dict)

# %%
# melt to get the ranks
rank_df = pd.melt(frame = word_df, id_vars = ['word_id', 'lcase', 'n_chars'],
                  value_vars = ['n_from_rank','n_to_rank'],
                  var_name = 'direction', value_name = 'word_rank')

# %%
recode_dict = {'n_from_rank':'from',
               'n_to_rank':'to'}

# %%
rank_df['direction'] = rank_df['direction'].map(recode_dict)

# %%
wc_df.head()

# %%
# join
wg_df = pd.merge(left = wc_df, right = rank_df)

# %%
wg_df.head()

# %%
wg_df.shape

# %%
wg_df['word_rank'].value_counts()

# %%
wg_df = wg_df.loc[wg_df['word_rank'] <= 5, :]

# %%
wg_df.shape

# %%
# now, 
def remove_html_tags(text):
    parser = etree.HTMLParser()
    tree = etree.fromstring(text, parser)
    return ''.join(tree.itertext())

def get_definitions(word):
    print(word)
    url = f"https://en.wiktionary.org/api/rest_v1/page/definition/{word}"
    response = requests.get(url)
    data = response.json()
    lang_keys = list(data.keys())
    if 'en' in data:
        def_list = data['en'][0]['definitions']
       
        clean_string = ''
        for ii in range(0, len(def_list)):
            curr_def = def_list[ii]['definition']     
            print('here')  
            print(curr_def)
            
            clean_string = clean_string + ' ' + curr_def 
    else:
        clean_string = 'not an english word'
    return (lang_keys, clean_string)

# %%
#outcome =  wg_df['lcase'].map(get_definitions)

# %%
#wg_df['lang_keys'] = outcome.map(lambda x: x[0])

# %%
#wg_df['word_definition'] = outcome.map(lambda x: x[1])

# %%
#wg_df.head()

# %%
#wg_df['word_definition_clean'] = wg_df['word_definition'].map(remove_html_tags)

# %%
wg_df.tail()

# %%
# wg_df['word_definition'].value_counts()

# %%
# export the words, chars, direction, and count to a javascript file for later use

# %%
wg_df.head()

# %%
# write out the words
temp_output_df = wg_df[['lcase', 'n_chars', 'direction', 'n_words', 'word_rank']]
temp_output_df.columns = ['word', 'number of characters','direction', 'number of words', 'word rank']
temp_output_df.to_json('../webpage/words.json',orient='records')

# %% [markdown]
# # WORD COUNTS

# %%
# join in word_group_id
sql = 'select * from word_counts;'
word_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
# Out:
# ...query execution took: 1.69 seconds...

# %%
word_df.head()
# Out:
#     word  lcase  n_chars first_letter  word_id  word_group_id letter_group  \
# 0      A      a        1            a        0              0            a
# 1     aa     aa        2            a        1              1            a
# 2    aal    aal        3            a        2              2           al
# 3  aalii  aalii        5            a        3              3          ail
# 4    aam    aam        3            a        4              4           am
#
#   letter_group_ranked  n_from_words  n_to_words
# 0                   a        144511           1
# 1                   a         45451           2
# 2                  la         24276           7
# 3                 lai          5358          15
# 4                  ma         14107           7

# %%
word_df['n_from_words'].sum()
# Out:
# 123758418

# %%
word_df['n_to_words'].sum()
# Out:
# 123758418

# %%
# what about the actual rows when storing this by word_group
# join in word_group_id
sql = 'select * from words_me_01;'
word_group_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
# Out:
# ...query execution took: 0.85 seconds...

# %%
word_group_df['n_from_word_groups'].sum()
# Out:
# 73218235

# %%
word_group_df['n_to_word_groups'].sum()
# Out:
# 73179245

# %%
# those numbers should be the same...

# %%
# turn this into the word_group_df
wg_df = word_df.drop_duplicates(subset=['word_group_id']).copy()

# %%
wg_df.head()
# Out:
#     word  lcase  n_chars first_letter  word_id  word_group_id letter_group  \
# 0      A      a        1            a        0              0            a
# 1     aa     aa        2            a        1              1            a
# 2    aal    aal        3            a        2              2           al
# 3  aalii  aalii        5            a        3              3          ail
# 4    aam    aam        3            a        4              4           am
#
#   letter_group_ranked  n_from_words  n_to_words
# 0                   a        144511           1
# 1                   a         45451           2
# 2                  la         24276           7
# 3                 lai          5358          15
# 4                  ma         14107           7

# %%
wg_df.shape
# Out:
# (215842, 10)

# %%
# rank
wg_df['n_from_rank'] = wg_df[['n_chars', 'n_from_words']].groupby(['n_chars']).rank(method = 'first', ascending=False)
wg_df['n_to_rank'] = wg_df[['n_chars', 'n_to_words']].groupby(['n_chars']).rank(method = 'first',ascending=False)

# melt to get the word count
wc_df = pd.melt(frame = wg_df, id_vars = ['word_id', 'word_group_id', 'lcase', 'n_chars'],
                  value_vars = ['n_from_words','n_to_words'],
                  var_name = 'direction', value_name = 'n_words')
				  
				  
recode_dict = {'n_from_words':'from',
               'n_to_words':'to'}


wc_df['direction'] = wc_df['direction'].map(recode_dict)			   
				  
				  
# melt to get the ranks
rank_df = pd.melt(frame = wg_df, id_vars = ['word_id', 'word_group_id', 'lcase', 'n_chars'],
                  value_vars = ['n_from_rank','n_to_rank'],
                  var_name = 'direction', value_name = 'word_rank')			  
				  
				  
recode_dict = {'n_from_rank':'from',
               'n_to_rank':'to'}

rank_df['direction'] = rank_df['direction'].map(recode_dict)		   
				  
				  				  
# join
wg_df = pd.merge(left = wc_df, right = rank_df)

# %%
wg_df.head()
# Out:
#    word_id  word_group_id  lcase  n_chars direction  n_words  word_rank
# 0        0              0      a        1      from   144511        3.0
# 1        1              1     aa        2      from    45451       30.0
# 2        2              2    aal        3      from    24276      110.0
# 3        3              3  aalii        5      from     5358      757.0
# 4        4              4    aam        3      from    14107      284.0

# %%
curr_wg_df = wg_df.loc[wg_df['word_rank'] <= 5, :].copy()

# %%
curr_wg_df.shape
# Out:
# (240, 7)

# %%
word_group_id_counter = Counter(word_df['word_group_id'])

# %%
curr_wg_df['word_group_size'] = curr_wg_df['word_group_id'].map(word_group_id_counter)

# %%
curr_wg_df.head()
# Out:
#       word_id  word_group_id     lcase  n_chars direction  n_words  word_rank  \
# 0           0              0         a        1      from   144511        3.0
# 1194     1212           1194   acetoin        7      from     5188        3.0
# 2024     2054           2024  actioner        8      from     3206        1.0
# 2989     3028           2989        ae        2      from    91948        3.0
# 3092     3133           3092       aer        3      from    55024        1.0
#
#       word_group_size
# 0                   1
# 1194                5
# 2024                5
# 2989                2
# 3092                5

# %%
curr_wg_df = curr_wg_df.sort_values(by = ['n_chars', 'lcase'])
temp_output_df = curr_wg_df[['lcase', 'n_chars', 'direction', 'n_words', 'word_rank', 'word_group_size']]

temp_output_df.columns = ['word', 'number of characters','direction', 'number of words', 'word rank', 'word group size']
temp_output_df.to_json('../webpage/word_groups.json',orient='records')

# %%
curr_wg_df.shape
# Out:
# (240, 8)

# %%
curr_wg_df.head()
# Out:
#         word_id  word_group_id lcase  n_chars direction  n_words  word_rank  \
# 0             0              0     a        1      from   144511        3.0
# 215842        0              0     a        1        to        1        1.0
# 232355    16974          16513     b        1        to        1        2.0
# 242718    27937          26876     c        1        to        1        3.0
# 261526    47720          45684     d        1        to        1        4.0
#
#         word_group_size
# 0                     1
# 215842                1
# 232355                1
# 242718                1
# 261526                1

# %%
# the from word id df
sql = 'select word_group_id, word_id, lcase, n_chars from words;'
fw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
fw_df.columns = ['from_word_group_id', 'from_word_id', 'from_word', 'from_n_chars']

# the to word id df
sql = 'select word_group_id, word_id, lcase, n_chars from words;'
tw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
tw_df.columns = ['to_word_group_id', 'to_word_id', 'to_word', 'to_n_chars']
# Out:
# ...query execution took: 0.99 seconds...
# ...query execution took: 0.77 seconds...

# %%
tw_df.head()
# Out:
#    to_word_group_id  to_word_id to_word  to_n_chars
# 0                 0           0       a           1
# 1                 1           1      aa           2
# 2                 2           2     aal           3
# 3                 3           3   aalii           5
# 4                 4           4     aam           3

# %%
# output path
word_list_output_path = '../webpage/word_list'

# %%
def save_words(df:pd.DataFrame, r_direction:str, curr_word:str):
    if r_direction == 'from':
        r_direction_opp = 'to'
    else:
        r_direction_opp = 'from'
    # the output file and name
    output_file_name = f'{r_direction}_{curr_word}.txt'
    ofpn = os.path.join(word_list_output_path, output_file_name)
    
    with open(file = ofpn, mode = 'w') as my_file:
        if df.empty:            
            my_file.write(f"## THERE ARE NO {r_direction_opp} WORDS FOR {curr_word} ## \n")
        else:

            # number of characters to iterate through
            nchar_list = sorted(df[f'{r_direction_opp}_n_chars'].unique().tolist(), reverse=True)
        
            for nc in nchar_list:
                my_file.write(f"##########\n")
                my_file.write(f"## WORDS OF LENGTH {nc} ## \n")
                my_file.write(f"##########\n")
                # subset by 
                temp_df = df.loc[df[f'{r_direction_opp}_n_chars' ]==nc, [f'{r_direction_opp}_word']].copy()
                temp_df = temp_df.drop_duplicates().sort_values(by = f'{r_direction_opp}_word')
                for fw in temp_df[f'{r_direction_opp}_word'].tolist():
                    my_file.write(fw + '  \n')

# %%
col_names = ['word_group_id', 'lcase']
temp_word_df = word_df[col_names].sort_values(by = col_names).drop_duplicates(subset = 'word_group_id')

# %%
# dictionary of words!
word_group_dict = {wg_id:word for wg_id, word in zip(temp_word_df['word_group_id'],
                                                     temp_word_df['lcase'])}

# %%
# counters
to_word_counter = Counter()
from_word_counter = Counter()
#test_wg_df = curr_wg_df.iloc]
for i_c, row in curr_wg_df.iterrows():    

    # the current word
    curr_word = word_group_dict[row['word_group_id']]    

    if row['direction'] == 'to':
        print('#### TO WORDS')

        # to words
        sql = f'select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = {row['word_group_id']};'
        print(sql)
        wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
        print(wg_df.shape)
        wg_df = pd.merge(left = wg_df, right = fw_df)
        wg_df = pd.merge(left = wg_df, right = tw_df)
        print(wg_df.shape)

        # save it
        save_words(df = wg_df, r_direction='to', curr_word=curr_word)
        
        # distinct from words
        from_word_counter.update(wg_df['from_word_id'])

    if row['direction'] == 'from':
        print('#### FROM WORDS')
        # from words
        sql = f'select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = {row['word_group_id']};'
        print(sql)
        wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
        print(wg_df.shape)
        wg_df = pd.merge(left = wg_df, right = fw_df)
        wg_df = pd.merge(left = wg_df, right = tw_df)
        print(wg_df.shape)

        # save it
        save_words(df = wg_df, r_direction='from', curr_word=curr_word)
        

        # distinct to words
        to_word_counter.update(wg_df['to_word_id'])
# Out:
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 0;
# ...query execution took: 0.0 seconds...
# (1, 2)
# (1, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 0;
# ...query execution took: 0.26 seconds...
# (133001, 2)
# (144511, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 16513;
# ...query execution took: 0.08 seconds...
# (35319, 2)
# (37353, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 26876;
# ...query execution took: 0.2 seconds...
# (80811, 2)
# (85776, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 45684;
# ...query execution took: 0.14 seconds...
# (56705, 2)
# (60650, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 56000;
# ...query execution took: 0.0 seconds...
# (1, 2)
# (1, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 56000;
# ...query execution took: 0.32 seconds...
# (145106, 2)
# (157437, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 85748;
# ...query execution took: 0.0 seconds...
# (1, 2)
# (1, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 120747;
# ...query execution took: 0.0 seconds...
# (1, 2)
# (1, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 151804;
# ...query execution took: 0.0 seconds...
# (1, 2)
# (1, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14;
# ...query execution took: 0.05 seconds...
# (23469, 2)
# (49666, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 2135;
# ...query execution took: 0.08 seconds...
# (34269, 2)
# (73244, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 2989;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (8, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 2989;
# ...query execution took: 0.18 seconds...
# (84952, 2)
# (183896, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 4192;
# ...query execution took: 0.08 seconds...
# (34218, 2)
# (72018, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 4240;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 4420;
# ...query execution took: 0.02 seconds...
# (7764, 2)
# (16476, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 60945;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (8, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 86273;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 182936;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 3092;
# ...query execution took: 0.0 seconds...
# (7, 2)
# (70, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 3092;
# ...query execution took: 0.1 seconds...
# (50748, 2)
# (275120, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 3273;
# ...query execution took: 0.07 seconds...
# (36099, 2)
# (115032, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 4390;
# ...query execution took: 0.1 seconds...
# (49169, 2)
# (208692, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 7151;
# ...query execution took: 0.02 seconds...
# (8250, 2)
# (34008, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 14537;
# ...query execution took: 0.0 seconds...
# (7, 2)
# (65, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14537;
# ...query execution took: 0.13 seconds...
# (49139, 2)
# (264205, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 92864;
# ...query execution took: 0.0 seconds...
# (6, 2)
# (16, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 115538;
# ...query execution took: 0.0 seconds...
# (7, 2)
# (9, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 186524;
# ...query execution took: 0.0 seconds...
# (7, 2)
# (8, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 3272;
# ...query execution took: 0.03 seconds...
# (9279, 2)
# (38292, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 4327;
# ...query execution took: 0.0 seconds...
# (13, 2)
# (48, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 9026;
# ...query execution took: 0.06 seconds...
# (27501, 2)
# (234512, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 13144;
# ...query execution took: 0.06 seconds...
# (20717, 2)
# (109915, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14568;
# ...query execution took: 0.05 seconds...
# (20724, 2)
# (131688, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 94028;
# ...query execution took: 0.0 seconds...
# (14, 2)
# (24, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 94036;
# ...query execution took: 0.0 seconds...
# (14, 2)
# (88, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 94037;
# ...query execution took: 0.0 seconds...
# (13, 2)
# (132, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 152622;
# ...query execution took: 0.0 seconds...
# (14, 2)
# (128, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 152622;
# ...query execution took: 0.06 seconds...
# (30564, 2)
# (131552, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 9202;
# ...query execution took: 0.02 seconds...
# (11338, 2)
# (47456, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 10659;
# ...query execution took: 0.03 seconds...
# (16316, 2)
# (69632, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 12855;
# ...query execution took: 0.0 seconds...
# (28, 2)
# (335, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 12921;
# ...query execution took: 0.02 seconds...
# (8666, 2)
# (81756, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14219;
# ...query execution took: 0.03 seconds...
# (12551, 2)
# (79632, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 59625;
# ...query execution took: 0.0 seconds...
# (28, 2)
# (256, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 61072;
# ...query execution took: 0.0 seconds...
# (25, 2)
# (162, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 89108;
# ...query execution took: 0.0 seconds...
# (24, 2)
# (235, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 99382;
# ...query execution took: 0.02 seconds...
# (9471, 2)
# (69433, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 116728;
# ...query execution took: 0.0 seconds...
# (30, 2)
# (114, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 12596;
# ...query execution took: 0.0 seconds...
# (50, 2)
# (107, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 12995;
# ...query execution took: 0.0 seconds...
# (56, 2)
# (256, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 14779;
# ...query execution took: 0.0 seconds...
# (55, 2)
# (393, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 86638;
# ...query execution took: 0.02 seconds...
# (5655, 2)
# (23596, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 93485;
# ...query execution took: 0.01 seconds...
# (6355, 2)
# (26352, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 115924;
# ...query execution took: 0.0 seconds...
# (54, 2)
# (745, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 115924;
# ...query execution took: 0.03 seconds...
# (11400, 2)
# (60570, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 119866;
# ...query execution took: 0.0 seconds...
# (52, 2)
# (210, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 131174;
# ...query execution took: 0.01 seconds...
# (4583, 2)
# (14280, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 160904;
# ...query execution took: 0.02 seconds...
# (8073, 2)
# (16874, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 1194;
# ...query execution took: 0.0 seconds...
# (95, 2)
# (915, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 4943;
# ...query execution took: 0.01 seconds...
# (3468, 2)
# (17900, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 13225;
# ...query execution took: 0.01 seconds...
# (2452, 2)
# (7569, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14229;
# ...query execution took: 0.01 seconds...
# (4644, 2)
# (29040, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 31357;
# ...query execution took: 0.0 seconds...
# (94, 2)
# (1146, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 57068;
# ...query execution took: 0.01 seconds...
# (3539, 2)
# (14508, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 59759;
# ...query execution took: 0.0 seconds...
# (102, 2)
# (1995, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 61166;
# ...query execution took: 0.0 seconds...
# (93, 2)
# (196, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 124521;
# ...query execution took: 0.0 seconds...
# (104, 2)
# (504, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 136845;
# ...query execution took: 0.01 seconds...
# (3109, 2)
# (16040, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 2024;
# ...query execution took: 0.01 seconds...
# (197, 2)
# (2355, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 13210;
# ...query execution took: 0.01 seconds...
# (207, 2)
# (2605, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 27725;
# ...query execution took: 0.0 seconds...
# (187, 2)
# (1257, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 59760;
# ...query execution took: 0.01 seconds...
# (1878, 2)
# (1918, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 60527;
# ...query execution took: 0.01 seconds...
# (1358, 2)
# (5572, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 109807;
# ...query execution took: 0.01 seconds...
# (976, 2)
# (995, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 123622;
# ...query execution took: 0.01 seconds...
# (197, 2)
# (1479, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 124520;
# ...query execution took: 0.0 seconds...
# (115, 2)
# (265, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 137423;
# ...query execution took: 0.01 seconds...
# (1611, 2)
# (3320, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 186533;
# ...query execution took: 0.0 seconds...
# (1309, 2)
# (1339, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 4891;
# ...query execution took: 0.01 seconds...
# (369, 2)
# (3536, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 14856;
# ...query execution took: 0.01 seconds...
# (386, 2)
# (4560, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 14856;
# ...query execution took: 0.0 seconds...
# (1158, 2)
# (5940, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 94041;
# ...query execution took: 0.01 seconds...
# (166, 2)
# (353, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 98222;
# ...query execution took: 0.0 seconds...
# (986, 2)
# (3006, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 102199;
# ...query execution took: 0.0 seconds...
# (505, 2)
# (1042, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 116060;
# ...query execution took: 0.0 seconds...
# (635, 2)
# (1923, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 141728;
# ...query execution took: 0.0 seconds...
# (825, 2)
# (1686, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 142601;
# ...query execution took: 0.01 seconds...
# (368, 2)
# (2394, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 165251;
# ...query execution took: 0.01 seconds...
# (239, 2)
# (561, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 43023;
# ...query execution took: 0.01 seconds...
# (511, 2)
# (4576, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 85991;
# ...query execution took: 0.01 seconds...
# (457, 2)
# (2020, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 91628;
# ...query execution took: 0.0 seconds...
# (403, 2)
# (812, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 101337;
# ...query execution took: 0.01 seconds...
# (313, 2)
# (680, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 102789;
# ...query execution took: 0.0 seconds...
# (241, 2)
# (484, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 112461;
# ...query execution took: 0.0 seconds...
# (161, 2)
# (330, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 131904;
# ...query execution took: 0.0 seconds...
# (400, 2)
# (410, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 142504;
# ...query execution took: 0.01 seconds...
# (666, 2)
# (1449, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 153359;
# ...query execution took: 0.01 seconds...
# (313, 2)
# (644, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 171561;
# ...query execution took: 0.0 seconds...
# (261, 2)
# (267, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 43025;
# ...query execution took: 0.02 seconds...
# (640, 2)
# (2570, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 90445;
# ...query execution took: 0.0 seconds...
# (170, 2)
# (171, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 90838;
# ...query execution took: 0.01 seconds...
# (425, 2)
# (819, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 91783;
# ...query execution took: 0.02 seconds...
# (858, 2)
# (5529, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 115726;
# ...query execution took: 0.0 seconds...
# (120, 2)
# (122, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 115768;
# ...query execution took: 0.02 seconds...
# (814, 2)
# (3320, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 141899;
# ...query execution took: 0.0 seconds...
# (87, 2)
# (87, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 154667;
# ...query execution took: 0.01 seconds...
# (443, 2)
# (1776, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 172225;
# ...query execution took: 0.0 seconds...
# (155, 2)
# (155, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 179210;
# ...query execution took: 0.0 seconds...
# (136, 2)
# (136, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 44316;
# ...query execution took: 0.0 seconds...
# (38, 2)
# (38, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 71923;
# ...query execution took: 0.0 seconds...
# (26, 2)
# (26, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 90447;
# ...query execution took: 0.02 seconds...
# (1535, 2)
# (3048, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 116111;
# ...query execution took: 0.0 seconds...
# (28, 2)
# (28, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 124602;
# ...query execution took: 0.01 seconds...
# (667, 2)
# (1070, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 131348;
# ...query execution took: 0.01 seconds...
# (430, 2)
# (632, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 144802;
# ...query execution took: 0.01 seconds...
# (856, 2)
# (1692, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148759;
# ...query execution took: 0.0 seconds...
# (58, 2)
# (58, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 150641;
# ...query execution took: 0.01 seconds...
# (879, 2)
# (1331, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 189508;
# ...query execution took: 0.0 seconds...
# (44, 2)
# (44, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 48543;
# ...query execution took: 0.0 seconds...
# (4, 2)
# (4, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 61036;
# ...query execution took: 0.03 seconds...
# (1095, 2)
# (1780, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 79995;
# ...query execution took: 0.01 seconds...
# (795, 2)
# (1190, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 134089;
# ...query execution took: 0.0 seconds...
# (26, 2)
# (26, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 136600;
# ...query execution took: 0.02 seconds...
# (538, 2)
# (745, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 139543;
# ...query execution took: 0.0 seconds...
# (6, 2)
# (6, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 141917;
# ...query execution took: 0.0 seconds...
# (10, 2)
# (10, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 148913;
# ...query execution took: 0.01 seconds...
# (556, 2)
# (763, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 187590;
# ...query execution took: 0.01 seconds...
# (724, 2)
# (1135, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 193503;
# ...query execution took: 0.0 seconds...
# (10, 2)
# (10, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33461;
# ...query execution took: 0.01 seconds...
# (392, 2)
# (531, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 39812;
# ...query execution took: 0.01 seconds...
# (701, 2)
# (1071, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 43986;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 106613;
# ...query execution took: 0.0 seconds...
# (4, 2)
# (4, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 123972;
# ...query execution took: 0.01 seconds...
# (800, 2)
# (1212, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 136546;
# ...query execution took: 0.01 seconds...
# (600, 2)
# (812, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 138038;
# ...query execution took: 0.0 seconds...
# (2, 2)
# (2, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 155457;
# ...query execution took: 0.02 seconds...
# (1152, 2)
# (2096, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 174231;
# ...query execution took: 0.0 seconds...
# (9, 2)
# (9, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 178366;
# ...query execution took: 0.0 seconds...
# (11, 2)
# (11, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9436;
# ...query execution took: 0.03 seconds...
# (1514, 2)
# (2288, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9451;
# ...query execution took: 0.02 seconds...
# (821, 2)
# (1267, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33460;
# ...query execution took: 0.02 seconds...
# (435, 2)
# (579, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 48951;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 108850;
# ...query execution took: 0.02 seconds...
# (632, 2)
# (1870, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 128349;
# ...query execution took: 0.03 seconds...
# (1948, 2)
# (2892, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 133479;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 143530;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 149460;
# ...query execution took: 0.0 seconds...
# (4, 2)
# (4, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 189868;
# ...query execution took: 0.0 seconds...
# (4, 2)
# (4, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 34021;
# ...query execution took: 0.02 seconds...
# (929, 2)
# (1393, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 34040;
# ...query execution took: 0.01 seconds...
# (343, 2)
# (516, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 34129;
# ...query execution took: 0.01 seconds...
# (367, 2)
# (1140, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 88974;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 107999;
# ...query execution took: 0.0 seconds...
# (2, 2)
# (2, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 108852;
# ...query execution took: 0.02 seconds...
# (991, 2)
# (2740, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 136110;
# ...query execution took: 0.02 seconds...
# (832, 2)
# (2806, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148252;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 152066;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 174232;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 7730;
# ...query execution took: 0.02 seconds...
# (1295, 2)
# (1882, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9452;
# ...query execution took: 0.03 seconds...
# (1771, 2)
# (2657, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 15333;
# ...query execution took: 0.0 seconds...
# (2, 2)
# (2, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 62105;
# ...query execution took: 0.04 seconds...
# (1943, 2)
# (2872, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 110395;
# ...query execution took: 0.04 seconds...
# (2717, 2)
# (8472, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 128390;
# ...query execution took: 0.03 seconds...
# (2366, 2)
# (3697, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 143532;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148319;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 149140;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 163395;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9716;
# ...query execution took: 0.02 seconds...
# (1028, 2)
# (1497, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 15332;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 17456;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 34130;
# ...query execution took: 0.02 seconds...
# (874, 2)
# (2574, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 128664;
# ...query execution took: 0.03 seconds...
# (2410, 2)
# (3743, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148231;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 171800;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 174410;
# ...query execution took: 0.04 seconds...
# (2538, 2)
# (3777, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 179865;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 188950;
# ...query execution took: 0.02 seconds...
# (956, 2)
# (1421, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 7721;
# ...query execution took: 0.03 seconds...
# (1721, 2)
# (4736, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 7731;
# ...query execution took: 0.02 seconds...
# (1518, 2)
# (2132, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 12848;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 22637;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 53200;
# ...query execution took: 0.11 seconds...
# (2880, 2)
# (4075, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 107990;
# ...query execution took: 0.03 seconds...
# (1768, 2)
# (2597, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 136614;
# ...query execution took: 0.02 seconds...
# (919, 2)
# (2320, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148267;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148411;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 160074;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 7723;
# ...query execution took: 0.06 seconds...
# (3873, 2)
# (10184, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9461;
# ...query execution took: 0.02 seconds...
# (1071, 2)
# (1519, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33441;
# ...query execution took: 0.03 seconds...
# (1798, 2)
# (2407, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33442;
# ...query execution took: 0.04 seconds...
# (2180, 2)
# (3233, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33445;
# ...query execution took: 0.04 seconds...
# (2639, 2)
# (3451, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 42048;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 143510;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148308;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 172563;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 207046;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 8010;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9463;
# ...query execution took: 0.04 seconds...
# (2829, 2)
# (3952, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 33186;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 55581;
# ...query execution took: 0.02 seconds...
# (984, 2)
# (1223, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 57236;
# ...query execution took: 0.04 seconds...
# (2920, 2)
# (4232, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 81637;
# ...query execution took: 0.02 seconds...
# (1388, 2)
# (1967, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 106856;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148218;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 148443;
# ...query execution took: 0.13 seconds...
# (12512, 2)
# (16685, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148443;
# ...query execution took: 0.0 seconds...
# (3, 2)
# (3, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 7724;
# ...query execution took: 0.06 seconds...
# (4808, 2)
# (6101, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 11848;
# ...query execution took: 0.06 seconds...
# (5252, 2)
# (6775, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 22612;
# ...query execution took: 0.15 seconds...
# (11982, 2)
# (16271, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 22612;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33440;
# ...query execution took: 0.06 seconds...
# (4451, 2)
# (6451, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 33448;
# ...query execution took: 0.03 seconds...
# (2132, 2)
# (5260, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 108651;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 114835;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 139613;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 185024;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 9464;
# ...query execution took: 0.06 seconds...
# (4615, 2)
# (5978, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 22633;
# ...query execution took: 0.16 seconds...
# (16832, 2)
# (22142, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 22633;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 60233;
# ...query execution took: 0.04 seconds...
# (2366, 2)
# (3143, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 69033;
# ...query execution took: 0.09 seconds...
# (8014, 2)
# (10285, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 71851;
# ...query execution took: 0.04 seconds...
# (3144, 2)
# (4763, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 129140;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148444;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 148445;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 162027;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 69032;
# ...query execution took: 0.08 seconds...
# (6124, 2)
# (8213, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 69032;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 131351;
# ...query execution took: 0.05 seconds...
# (1947, 2)
# (2460, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 131351;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 162029;
# ...query execution took: 0.04 seconds...
# (3524, 2)
# (4849, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 162029;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 184386;
# ...query execution took: 0.05 seconds...
# (4685, 2)
# (6545, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 184386;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id = 186371;
# ...query execution took: 0.06 seconds...
# (5016, 2)
# (6491, 8)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id = 186371;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 8)

# %%
wg_df.head()
# Out:
#    from_word_group_id  to_word_group_id  from_word_id  to_word_id
# 0                   6             45684             6       47720
# 1                   7             45684             7       47720
# 2                  16             45684            16       47720
# 3                  33             45684            33       47720
# 4                  38             45684            38       47720

# %%
word_df.head()
# Out:
#     word  lcase  n_chars first_letter  word_id  word_group_id letter_group  \
# 0      A      a        1            a        0              0            a
# 1     aa     aa        2            a        1              1            a
# 2    aal    aal        3            a        2              2           al
# 3  aalii  aalii        5            a        3              3          ail
# 4    aam    aam        3            a        4              4           am
#
#   letter_group_ranked  n_from_words  n_to_words
# 0                   a        144511           1
# 1                   a         45451           2
# 2                  la         24276           7
# 3                 lai          5358          15
# 4                  ma         14107           7

# %%
# the letters in the top five words by word length can be found in:
print(len(from_word_counter)) 
# which is:
print(len(from_word_counter) / word_df.shape[0])
# of words

# %%
# the letters in the top five words by word length can be rearraged to spell:
print(len(to_word_counter))
# which is:
print(len(to_word_counter) / word_df.shape[0])
# of words

# %%
# what letters are represented?
from_letter_counter = Counter()
to_letter_counter = Counter()

# %%
for ir, row in curr_wg_df.iterrows():
    if row['direction'] == 'from':
        from_letter_counter.update(row['lcase'])
    if row['direction'] == 'to':
        to_letter_counter.update(row['lcase'])

# %%
from string import ascii_lowercase

# %%
from_letter_counter

# %%
set(ascii_lowercase).difference(from_letter_counter.keys())

# %%
curr_wg_df.shape

# %%
set(ascii_lowercase).difference(to_letter_counter.keys())

# %%
to_letter_counter
