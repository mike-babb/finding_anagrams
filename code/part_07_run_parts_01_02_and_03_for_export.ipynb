# %% [markdown]
# # Mike Babb
# # babb.mike@outlook.com
# # Find anagrams
# ## Part 7: Run part 01, part 02, and part 03

# %%
# standard libraries - installed by default
import csv
import os
import sqlite3
import time

# %%
# external libraries - not installed by default
import numpy as np
import pandas as pd

# %%
from part_00_process_functions import build_db_conn, query_db
import _run_constants as rc
from part_01_structure_data import run_part_01
from part_02_demonstrate_extraction_timing_techniques import run_part_02
from part_03_generate_and_store_anagrams import run_part_03

# %%
def run_part_07( in_file_path:str, in_file_name:str, base_output_file_path:str, db_path:str,
                db_name:str, data_output_file_path:str, matrix_extraction_option:int,
                n_subset_letters:int, letter_subset_list:None, write_data:bool):    

    # Part 01
    
    run_part_01(
            in_file_path=rc.in_file_path,
            in_file_name=rc.in_file_name,
            base_output_file_path=rc.base_output_file_path,
            db_name=rc.db_name,
        )
    
    # Part 02
    
    run_part_02(db_path=rc.db_path, db_name=rc.db_name,
               data_output_file_path=rc.data_output_file_path,
               n_subset_letters=3)
    
    
    # Part 03
    run_part_03(matrix_extraction_option=matrix_extraction_option, n_subset_letters=n_subset_letters, letter_subset_list=letter_subset_list,
           write_data=write_data, db_path=db_path, db_name=db_name, in_file_path=in_file_path)

# %%
if __name__ == '__main__':
    ####
    # process control flags
    ####
    
    # Use numpy to perform matrix opertions and determine from/to and exact anagram relationships
    # Option 1: Full matrix
    # Option 2: Word-length
    # Option 3: First letter
    # Option 4: Single-least common letter
    # Option 5: n least common letters
    # Option 6: word-length and n least common letters
    
    matrix_extraction_option = 5
    
    # max number of letters to slice to use for the generation of sub-matrices for
    # options 5 and 6. More letters means more sub-matrices
    # 3 seems to be the sweet spot
    n_subset_letters = 3
    
    # set write_data to True to store the generated list of anagrams
    write_data = False
    
    # Testing options
    # NoneL to include all letters
    # ['q', 'x'] or a different set of letters to test a specific letter
    # 'SAMPLE' to take a 10% sample by word length group
    # letter_subset_list = ['x']
    # letter_subset_list = 'SAMPLE'
    letter_subset_list = None

    run_part_07( in_file_path = rc.in_file_path, in_file_name = rc.in_file_name, base_output_file_path = rc.base_output_file_path,
                db_path = rc.db_path, db_name = rc.db_name, data_output_file_path = rc.data_output_file_path,
                matrix_extraction_option = matrix_extraction_option, n_subset_letters = n_subset_letters,
                letter_subset_list =None, write_data = False)
# Out:
# ...Reading in list of words...
# ...found 235,886 words to find relationships for...
# ...computing the word group id...
# ...counting letter frequencies...
# ...creating letter groups...
# ...populating the character matrix...
# ...creating the word group dataframe...
# ...saving the character matrix...
# ...saving the letter dictionary...
# ...saving tables to database...
# ...now writing: words
# ...now writing: word_groups
# ...now writing: letter_count
# ...loading words into a dataframe...
# ...query execution took: 1.71 seconds...
# ...loading word groups into a dataframe...
# ...query execution took: 1.75 seconds...
# ...loading the letter dictionary...
# ...loading the char matrix...
# ...subsetting the char matrix...
# *** matrix extraction option: 0 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...16,101 sub-matrices created...
# Total extraction time: 47.2 seconds.
# *** matrix extraction option: 1 ***
# ...0 sub-matrices created...
# Total extraction time: 1.25 seconds.
# *** matrix extraction option: 2 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...24 sub-matrices created...
# Total extraction time: 8.91 seconds.
# *** matrix extraction option: 3 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...26 sub-matrices created...
# Total extraction time: 9.37 seconds.
# *** matrix extraction option: 4 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...26 sub-matrices created...
# Total extraction time: 8.52 seconds.
# *** matrix extraction option: 5 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...2,387 sub-matrices created...
# Total extraction time: 8.89 seconds.
# *** matrix extraction option: 6 ***
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...16,101 sub-matrices created...
# Total extraction time: 59.32 seconds.
#    matrix_extraction_option n_char_matrix_dict_type  \
# 0                         0          <class 'dict'>
# 1                         1      <class 'NoneType'>
# 2                         2          <class 'dict'>
# 3                         3      <class 'NoneType'>
# 4                         4      <class 'NoneType'>
# 5                         5      <class 'NoneType'>
# 6                         6      <class 'NoneType'>
#
#   single_letter_matrix_dict_type letter_selector_matrix_dict_type  \
# 0                 <class 'dict'>                   <class 'dict'>
# 1             <class 'NoneType'>               <class 'NoneType'>
# 2             <class 'NoneType'>               <class 'NoneType'>
# 3                 <class 'dict'>               <class 'NoneType'>
# 4                 <class 'dict'>               <class 'NoneType'>
# 5             <class 'NoneType'>                   <class 'dict'>
# 6             <class 'NoneType'>               <class 'NoneType'>
#
#   nc_ls_matrix_dict_type  n_char_matrix_dict_items  \
# 0         <class 'dict'>                        24
# 1     <class 'NoneType'>                        -1
# 2     <class 'NoneType'>                        24
# 3     <class 'NoneType'>                        -1
# 4     <class 'NoneType'>                        -1
# 5     <class 'NoneType'>                        -1
# 6         <class 'dict'>                        -1
#
#    single_letter_matrix_dict_items  letter_selector_matrix_dict_items  \
# 0                               26                               2387
# 1                               -1                                 -1
# 2                               -1                                 -1
# 3                               26                                 -1
# 4                               26                                 -1
# 5                               -1                               2387
# 6                               -1                                 -1
#
#    nc_ls_matrix_dict_items  process_time
# 0                    16101         47.20
# 1                       -1          1.25
# 2                       -1          8.91
# 3                       -1          9.37
# 4                       -1          8.52
# 5                       -1          8.89
# 6                    16101         59.32
# ...now writing: matrix_extraction_technique_timing
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...16,101 sub-matrices created...
# Total extraction time: 53.38 seconds.
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# There are 45 parent/from word groups for the word achiever
# There are 46 parent/from words for the word achiever
# The first five words are:
# 1348               achiever
# 12440          archdeceiver
# 12445         archdetective
# 12624          architective
# 12737    archrepresentative
# Name: lcase, dtype: object
# The last five words are:
# 224512       urethrovesical
# 225856        vaucheriaceae
# 225857       vaucheriaceous
# 227047    vibrotherapeutics
# 233655       zepharovichite
# Name: lcase, dtype: object
# Matrix Selection Option 1: Selecting by full matrix
# Total time: 2.37 seconds. Average time: 0.02 seconds.
#
# Matrix Selection Option 2: Selecting by word length
# Total time: 1.83 seconds. Average time: 0.02 seconds.
#
# Matrix Selection Option 3: Selecting by first letter
# Total time: 1.49 seconds. Average time: 0.01 seconds.
#
# Matrix Selection Option 4: Selecting by single least common letter
# Total time: 0.23 seconds. Average time: 0.0 seconds.
#
# Matrix Selection Option 5: Selecting by letter selector
# Total time: 0.02 seconds. Average time: 0.0 seconds.
#
# Matrix Selection Option 6: Selecting by word length and letter selector
# Total time: 0.01 seconds. Average time: 0.0 seconds.
#
#      source    target  source_timing  target_timing  timing_ratio
# 0  Option 1  Option 1       2.365606       2.365606      1.000000
# 1  Option 1  Option 2       2.365606       1.827156      1.294693
# 2  Option 1  Option 3       2.365606       1.489246      1.588459
# 3  Option 1  Option 4       2.365606       0.225804     10.476382
# 4  Option 1  Option 5       2.365606       0.016135    146.613313
#   Matrix Extraction  Option 1  Option 2  Option 3   Option 4    Option 5  \
# 0          Option 1  1.000000  1.294693  1.588459  10.476382  146.613313
# 1          Option 2  0.772384  1.000000  1.226900   8.091788  113.241754
# 2          Option 3  0.629541  0.815062  1.000000   6.595312   92.299095
# 3          Option 4  0.095453  0.123582  0.151623   1.000000   13.994651
# 4          Option 5  0.006821  0.008831  0.010834   0.071456    1.000000
# 5          Option 6  0.006314  0.008175  0.010030   0.066153    0.925782
#
#      Option 6
# 0  158.366915
# 1  122.320047
# 2   99.698470
# 3   15.116566
# 4    1.080167
# 5    1.000000
# ...now writing: matrix_extraction_timing
# ...now writing: word_group_lookup_counts
# ...estimated number of from/to pair word pairs: 198,842,245
# ...now writing: n_possible_anagrams
# ...loading words into a dataframe...
# ...query execution took: 1.5 seconds...
# ...loading word groups into a dataframe...
# ...query execution took: 1.64 seconds...
# ...loading the letter dictionary...
# ...loading the char matrix...
# ...subsetting the char matrix...
# ...enumerating 16,101 records...
# ...1,000 records enumerated...
# ...2,000 records enumerated...
# ...3,000 records enumerated...
# ...4,000 records enumerated...
# ...5,000 records enumerated...
# ...6,000 records enumerated...
# ...7,000 records enumerated...
# ...8,000 records enumerated...
# ...9,000 records enumerated...
# ...10,000 records enumerated...
# ...11,000 records enumerated...
# ...12,000 records enumerated...
# ...13,000 records enumerated...
# ...14,000 records enumerated...
# ...15,000 records enumerated...
# ...16,000 records enumerated...
# ...2,387 sub-matrices created...
# Total extraction time: 8.87 seconds.
# ...query execution took: 0.0 seconds...
# ...finding parent anagrams for 215,842 words...
# ...found parent anagrams for 10,000 words...
# ...found parent anagrams for 20,000 words...
# ...found parent anagrams for 30,000 words...
# ...found parent anagrams for 40,000 words...
# ...found parent anagrams for 50,000 words...
# ...found parent anagrams for 60,000 words...
# ...found parent anagrams for 70,000 words...
# ...found parent anagrams for 80,000 words...
# ...found parent anagrams for 90,000 words...
# ...found parent anagrams for 100,000 words...
# ...found parent anagrams for 110,000 words...
# ...found parent anagrams for 120,000 words...
# ...found parent anagrams for 130,000 words...
# ...found parent anagrams for 140,000 words...
# ...found parent anagrams for 150,000 words...
# ...found parent anagrams for 160,000 words...
# ...found parent anagrams for 170,000 words...
# ...found parent anagrams for 180,000 words...
# ...found parent anagrams for 190,000 words...
# ...found parent anagrams for 200,000 words...
# ...found parent anagrams for 210,000 words...
# ...found parent anagrams for 215,842 words...
# ...finding parent anagrams for 215,842 words took 213.5 seconds | 3.56 minutes...
# ...truncating output list...
# ...populating the count of to-words...
# ...total anagram pairs: 73,179,245
# ...now writing: words_me_05
# ...anagram discovery time: 213.5 seconds | 3.56 minutes
# ...total processing time: 238.09 seconds | 3.97 minutes
