# %% [markdown]
# # Mike Babb
# # babb.mike@outlook.com
# # Find anagrams
# ## Part 10: Create the count of parent / child words by word - not just word group

# %%
# standard
from collections import Counter
import os
import sqlite3

# %%
# external
import pandas as pd

# %%
# custom
import _run_constants as rc
from part_00_file_db_utils import query_db, write_data_to_sqlite

# %% [markdown]
# # Libraries

# %%
db_path_name = os.path.join(rc.db_path, rc.db_name)

# %%
# break up the sql calls into batches of 1000 word groups
cuts = list(range(0, 217001, 1000))

# %%
# the from word id df
sql = 'select word_group_id, word_id from words;'
fw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
fw_df.columns = ['from_word_group_id', 'from_word_id']

# the to word id df
sql = 'select word_group_id, word_id from words;'
tw_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
tw_df.columns = ['to_word_group_id', 'to_word_id']
# Out:
# ...query execution took: 0.77 seconds...
# ...query execution took: 0.49 seconds...

# %%
# counters
to_word_counter = Counter()
from_word_counter = Counter()
# enumerate the cuts, send to the SQLiteDB, get the data, and aggregate
for i_c, ii in enumerate(cuts[:-1]):
    print('#### TO WORDS')
    # to words
    sql = f'select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= {ii} and to_word_group_id < {cuts[i_c+ 1]};'
    
    print(sql)
    wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
    print(wg_df.shape)
    # exapnd the from words
    wg_df = pd.merge(left = wg_df, right = fw_df)
    # expand the to words
    wg_df = pd.merge(left = wg_df, right = tw_df)
    
    wg_df = wg_df.drop_duplicates()
    print(wg_df.shape)    

    # count - and this is where it gets counter intuitive.
    # The to word counts are counts of from-to word pairs
    from_word_counter.update(wg_df['to_word_id'])

    print('#### FROM WORDS')
    # from words
    sql = f'select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= {ii} and from_word_group_id < {cuts[i_c+ 1]};'
    print(sql)
    wg_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
    print(wg_df.shape)
    wg_df = pd.merge(left = wg_df, right = fw_df)
    wg_df = pd.merge(left = wg_df, right = tw_df)
    

    wg_df = wg_df.drop_duplicates()
    print(wg_df.shape)

    # count each word id to get th
    # the from word counts is the from-to-wrd pairs
    to_word_counter.update(wg_df['from_word_id'])
# Out:
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 0 and to_word_group_id < 1000;
# ...query execution took: 2.2 seconds...
# (646189, 2)
# (1154202, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 0 and from_word_group_id < 1000;
# ...query execution took: 9.74 seconds...
# (252892, 2)
# (454071, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 1000 and to_word_group_id < 2000;
# ...query execution took: 2.04 seconds...
# (665626, 2)
# (1588634, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 1000 and from_word_group_id < 2000;
# ...query execution took: 7.9 seconds...
# (366055, 2)
# (661428, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 2000 and to_word_group_id < 3000;
# ...query execution took: 1.94 seconds...
# (595611, 2)
# (1397894, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 2000 and from_word_group_id < 3000;
# ...query execution took: 5.44 seconds...
# (302877, 2)
# (559882, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 3000 and to_word_group_id < 4000;
# ...query execution took: 1.49 seconds...
# (504168, 2)
# (1149394, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 3000 and from_word_group_id < 4000;
# ...query execution took: 4.36 seconds...
# (255081, 2)
# (474638, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 4000 and to_word_group_id < 5000;
# ...query execution took: 4.64 seconds...
# (1526068, 2)
# (3924060, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 4000 and from_word_group_id < 5000;
# ...query execution took: 3.06 seconds...
# (190795, 2)
# (383332, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 5000 and to_word_group_id < 6000;
# ...query execution took: 2.87 seconds...
# (883556, 2)
# (2183654, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 5000 and from_word_group_id < 6000;
# ...query execution took: 3.86 seconds...
# (239754, 2)
# (475491, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 6000 and to_word_group_id < 7000;
# ...query execution took: 1.91 seconds...
# (582289, 2)
# (1582367, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 6000 and from_word_group_id < 7000;
# ...query execution took: 4.49 seconds...
# (286861, 2)
# (516015, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 7000 and to_word_group_id < 8000;
# ...query execution took: 1.34 seconds...
# (445261, 2)
# (994335, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 7000 and from_word_group_id < 8000;
# ...query execution took: 5.63 seconds...
# (352378, 2)
# (637486, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 8000 and to_word_group_id < 9000;
# ...query execution took: 2.0 seconds...
# (648118, 2)
# (1525390, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 8000 and from_word_group_id < 9000;
# ...query execution took: 5.39 seconds...
# (353121, 2)
# (648060, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 9000 and to_word_group_id < 10000;
# ...query execution took: 0.41 seconds...
# (149114, 2)
# (464754, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 9000 and from_word_group_id < 10000;
# ...query execution took: 10.24 seconds...
# (654178, 2)
# (1111870, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 10000 and to_word_group_id < 11000;
# ...query execution took: 1.55 seconds...
# (508903, 2)
# (1051838, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 10000 and from_word_group_id < 11000;
# ...query execution took: 6.96 seconds...
# (453263, 2)
# (820554, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 11000 and to_word_group_id < 12000;
# ...query execution took: 1.51 seconds...
# (506070, 2)
# (983780, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 11000 and from_word_group_id < 12000;
# ...query execution took: 4.27 seconds...
# (279456, 2)
# (486512, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 12000 and to_word_group_id < 13000;
# ...query execution took: 2.58 seconds...
# (866391, 2)
# (2456262, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 12000 and from_word_group_id < 13000;
# ...query execution took: 7.74 seconds...
# (389034, 2)
# (704610, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 13000 and to_word_group_id < 14000;
# ...query execution took: 2.57 seconds...
# (857145, 2)
# (2197506, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 13000 and from_word_group_id < 14000;
# ...query execution took: 4.57 seconds...
# (265618, 2)
# (511942, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 14000 and to_word_group_id < 15000;
# ...query execution took: 2.68 seconds...
# (846078, 2)
# (2250541, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 14000 and from_word_group_id < 15000;
# ...query execution took: 4.53 seconds...
# (289696, 2)
# (553774, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 15000 and to_word_group_id < 16000;
# ...query execution took: 1.01 seconds...
# (353272, 2)
# (511298, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 15000 and from_word_group_id < 16000;
# ...query execution took: 6.21 seconds...
# (408133, 2)
# (650424, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 16000 and to_word_group_id < 17000;
# ...query execution took: 0.89 seconds...
# (302501, 2)
# (511115, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 16000 and from_word_group_id < 17000;
# ...query execution took: 3.13 seconds...
# (219353, 2)
# (373367, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 17000 and to_word_group_id < 18000;
# ...query execution took: 0.96 seconds...
# (341290, 2)
# (663122, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 17000 and from_word_group_id < 18000;
# ...query execution took: 2.26 seconds...
# (163901, 2)
# (310160, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 18000 and to_word_group_id < 19000;
# ...query execution took: 0.78 seconds...
# (283877, 2)
# (497069, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 18000 and from_word_group_id < 19000;
# ...query execution took: 3.38 seconds...
# (212590, 2)
# (386948, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 19000 and to_word_group_id < 20000;
# ...query execution took: 0.81 seconds...
# (270870, 2)
# (440005, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 19000 and from_word_group_id < 20000;
# ...query execution took: 2.01 seconds...
# (127365, 2)
# (221442, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 20000 and to_word_group_id < 21000;
# ...query execution took: 0.94 seconds...
# (258569, 2)
# (398962, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 20000 and from_word_group_id < 21000;
# ...query execution took: 2.59 seconds...
# (168314, 2)
# (291382, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 21000 and to_word_group_id < 22000;
# ...query execution took: 0.67 seconds...
# (239651, 2)
# (360073, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 21000 and from_word_group_id < 22000;
# ...query execution took: 3.01 seconds...
# (204952, 2)
# (348987, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 22000 and to_word_group_id < 23000;
# ...query execution took: 0.61 seconds...
# (218834, 2)
# (328157, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 22000 and from_word_group_id < 23000;
# ...query execution took: 4.89 seconds...
# (341487, 2)
# (564181, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 23000 and to_word_group_id < 24000;
# ...query execution took: 0.97 seconds...
# (338532, 2)
# (551378, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 23000 and from_word_group_id < 24000;
# ...query execution took: 3.02 seconds...
# (144343, 2)
# (253398, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 24000 and to_word_group_id < 25000;
# ...query execution took: 0.45 seconds...
# (122054, 2)
# (158919, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 24000 and from_word_group_id < 25000;
# ...query execution took: 5.5 seconds...
# (311797, 2)
# (525987, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 25000 and to_word_group_id < 26000;
# ...query execution took: 0.4 seconds...
# (138281, 2)
# (205578, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 25000 and from_word_group_id < 26000;
# ...query execution took: 3.73 seconds...
# (220458, 2)
# (368132, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 26000 and to_word_group_id < 27000;
# ...query execution took: 1.19 seconds...
# (391257, 2)
# (528125, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 26000 and from_word_group_id < 27000;
# ...query execution took: 2.21 seconds...
# (144126, 2)
# (235691, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 27000 and to_word_group_id < 28000;
# ...query execution took: 1.39 seconds...
# (465002, 2)
# (821476, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 27000 and from_word_group_id < 28000;
# ...query execution took: 4.29 seconds...
# (245454, 2)
# (442550, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 28000 and to_word_group_id < 29000;
# ...query execution took: 1.56 seconds...
# (514859, 2)
# (980618, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 28000 and from_word_group_id < 29000;
# ...query execution took: 4.36 seconds...
# (258197, 2)
# (467302, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 29000 and to_word_group_id < 30000;
# ...query execution took: 1.59 seconds...
# (499913, 2)
# (1012483, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 29000 and from_word_group_id < 30000;
# ...query execution took: 4.56 seconds...
# (279562, 2)
# (508132, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 30000 and to_word_group_id < 31000;
# ...query execution took: 1.83 seconds...
# (590580, 2)
# (867736, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 30000 and from_word_group_id < 31000;
# ...query execution took: 4.94 seconds...
# (305163, 2)
# (550504, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 31000 and to_word_group_id < 32000;
# ...query execution took: 1.52 seconds...
# (494281, 2)
# (942586, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 31000 and from_word_group_id < 32000;
# ...query execution took: 6.29 seconds...
# (379810, 2)
# (682653, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 32000 and to_word_group_id < 33000;
# ...query execution took: 1.06 seconds...
# (353167, 2)
# (628246, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 32000 and from_word_group_id < 33000;
# ...query execution took: 4.08 seconds...
# (258506, 2)
# (444416, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 33000 and to_word_group_id < 34000;
# ...query execution took: 1.06 seconds...
# (325923, 2)
# (546897, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 33000 and from_word_group_id < 34000;
# ...query execution took: 8.3 seconds...
# (502743, 2)
# (825318, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 34000 and to_word_group_id < 35000;
# ...query execution took: 1.06 seconds...
# (340552, 2)
# (565519, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 34000 and from_word_group_id < 35000;
# ...query execution took: 6.4 seconds...
# (396614, 2)
# (639447, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 35000 and to_word_group_id < 36000;
# ...query execution took: 1.91 seconds...
# (619112, 2)
# (1045231, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 35000 and from_word_group_id < 36000;
# ...query execution took: 4.13 seconds...
# (230135, 2)
# (411263, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 36000 and to_word_group_id < 37000;
# ...query execution took: 1.01 seconds...
# (353431, 2)
# (469047, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 36000 and from_word_group_id < 37000;
# ...query execution took: 3.74 seconds...
# (231462, 2)
# (380975, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 37000 and to_word_group_id < 38000;
# ...query execution took: 1.2 seconds...
# (384772, 2)
# (557049, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 37000 and from_word_group_id < 38000;
# ...query execution took: 4.22 seconds...
# (262803, 2)
# (446139, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 38000 and to_word_group_id < 39000;
# ...query execution took: 0.36 seconds...
# (127017, 2)
# (143887, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 38000 and from_word_group_id < 39000;
# ...query execution took: 7.4 seconds...
# (469644, 2)
# (760069, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 39000 and to_word_group_id < 40000;
# ...query execution took: 0.46 seconds...
# (160568, 2)
# (263515, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 39000 and from_word_group_id < 40000;
# ...query execution took: 8.31 seconds...
# (499676, 2)
# (840516, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 40000 and to_word_group_id < 41000;
# ...query execution took: 1.91 seconds...
# (472135, 2)
# (792567, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 40000 and from_word_group_id < 41000;
# ...query execution took: 8.3 seconds...
# (408594, 2)
# (677954, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 41000 and to_word_group_id < 42000;
# ...query execution took: 2.66 seconds...
# (537636, 2)
# (843242, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 41000 and from_word_group_id < 42000;
# ...query execution took: 7.52 seconds...
# (385598, 2)
# (656805, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 42000 and to_word_group_id < 43000;
# ...query execution took: 0.63 seconds...
# (220537, 2)
# (309784, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 42000 and from_word_group_id < 43000;
# ...query execution took: 8.99 seconds...
# (587126, 2)
# (973631, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 43000 and to_word_group_id < 44000;
# ...query execution took: 1.36 seconds...
# (425513, 2)
# (628678, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 43000 and from_word_group_id < 44000;
# ...query execution took: 4.22 seconds...
# (267303, 2)
# (484118, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 44000 and to_word_group_id < 45000;
# ...query execution took: 1.43 seconds...
# (476516, 2)
# (668627, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 44000 and from_word_group_id < 45000;
# ...query execution took: 4.64 seconds...
# (276221, 2)
# (445708, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 45000 and to_word_group_id < 46000;
# ...query execution took: 0.9 seconds...
# (323610, 2)
# (618782, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 45000 and from_word_group_id < 46000;
# ...query execution took: 4.57 seconds...
# (304949, 2)
# (495095, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 46000 and to_word_group_id < 47000;
# ...query execution took: 1.29 seconds...
# (405011, 2)
# (844665, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 46000 and from_word_group_id < 47000;
# ...query execution took: 5.97 seconds...
# (247957, 2)
# (451753, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 47000 and to_word_group_id < 48000;
# ...query execution took: 0.92 seconds...
# (220489, 2)
# (467095, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 47000 and from_word_group_id < 48000;
# ...query execution took: 6.89 seconds...
# (313331, 2)
# (565769, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 48000 and to_word_group_id < 49000;
# ...query execution took: 0.87 seconds...
# (237856, 2)
# (492670, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 48000 and from_word_group_id < 49000;
# ...query execution took: 9.54 seconds...
# (492264, 2)
# (903618, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 49000 and to_word_group_id < 50000;
# ...query execution took: 0.69 seconds...
# (241312, 2)
# (474973, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 49000 and from_word_group_id < 50000;
# ...query execution took: 6.19 seconds...
# (407649, 2)
# (709419, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 50000 and to_word_group_id < 51000;
# ...query execution took: 0.64 seconds...
# (222526, 2)
# (420520, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 50000 and from_word_group_id < 51000;
# ...query execution took: 4.53 seconds...
# (300252, 2)
# (507949, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 51000 and to_word_group_id < 52000;
# ...query execution took: 0.87 seconds...
# (309052, 2)
# (618037, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 51000 and from_word_group_id < 52000;
# ...query execution took: 6.51 seconds...
# (386884, 2)
# (656852, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 52000 and to_word_group_id < 53000;
# ...query execution took: 0.18 seconds...
# (62234, 2)
# (73694, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 52000 and from_word_group_id < 53000;
# ...query execution took: 8.0 seconds...
# (531538, 2)
# (896149, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 53000 and to_word_group_id < 54000;
# ...query execution took: 0.88 seconds...
# (303313, 2)
# (638520, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 53000 and from_word_group_id < 54000;
# ...query execution took: 3.82 seconds...
# (258415, 2)
# (430492, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 54000 and to_word_group_id < 55000;
# ...query execution took: 1.42 seconds...
# (503229, 2)
# (912307, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 54000 and from_word_group_id < 55000;
# ...query execution took: 2.84 seconds...
# (199384, 2)
# (369595, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 55000 and to_word_group_id < 56000;
# ...query execution took: 1.06 seconds...
# (370668, 2)
# (564947, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 55000 and from_word_group_id < 56000;
# ...query execution took: 2.95 seconds...
# (205057, 2)
# (353907, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 56000 and to_word_group_id < 57000;
# ...query execution took: 2.71 seconds...
# (840209, 2)
# (1540429, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 56000 and from_word_group_id < 57000;
# ...query execution took: 3.89 seconds...
# (241864, 2)
# (432784, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 57000 and to_word_group_id < 58000;
# ...query execution took: 1.56 seconds...
# (531519, 2)
# (1267057, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 57000 and from_word_group_id < 58000;
# ...query execution took: 9.08 seconds...
# (620964, 2)
# (1026823, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 58000 and to_word_group_id < 59000;
# ...query execution took: 1.29 seconds...
# (446797, 2)
# (917859, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 58000 and from_word_group_id < 59000;
# ...query execution took: 6.25 seconds...
# (414446, 2)
# (738003, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 59000 and to_word_group_id < 60000;
# ...query execution took: 1.66 seconds...
# (573248, 2)
# (1360039, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 59000 and from_word_group_id < 60000;
# ...query execution took: 4.36 seconds...
# (290436, 2)
# (540022, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 60000 and to_word_group_id < 61000;
# ...query execution took: 0.92 seconds...
# (324197, 2)
# (603385, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 60000 and from_word_group_id < 61000;
# ...query execution took: 4.93 seconds...
# (328599, 2)
# (561338, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 61000 and to_word_group_id < 62000;
# ...query execution took: 2.68 seconds...
# (895795, 2)
# (1936796, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 61000 and from_word_group_id < 62000;
# ...query execution took: 5.07 seconds...
# (337353, 2)
# (614039, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 62000 and to_word_group_id < 63000;
# ...query execution took: 0.45 seconds...
# (160080, 2)
# (261034, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 62000 and from_word_group_id < 63000;
# ...query execution took: 4.09 seconds...
# (286414, 2)
# (475692, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 63000 and to_word_group_id < 64000;
# ...query execution took: 0.08 seconds...
# (31920, 2)
# (38236, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 63000 and from_word_group_id < 64000;
# ...query execution took: 4.62 seconds...
# (310156, 2)
# (522137, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 64000 and to_word_group_id < 65000;
# ...query execution took: 0.76 seconds...
# (268496, 2)
# (426901, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 64000 and from_word_group_id < 65000;
# ...query execution took: 3.51 seconds...
# (244664, 2)
# (414604, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 65000 and to_word_group_id < 66000;
# ...query execution took: 0.64 seconds...
# (234915, 2)
# (373132, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 65000 and from_word_group_id < 66000;
# ...query execution took: 2.57 seconds...
# (184378, 2)
# (324177, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 66000 and to_word_group_id < 67000;
# ...query execution took: 0.44 seconds...
# (161096, 2)
# (224806, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 66000 and from_word_group_id < 67000;
# ...query execution took: 2.68 seconds...
# (195937, 2)
# (329621, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 67000 and to_word_group_id < 68000;
# ...query execution took: 0.34 seconds...
# (109999, 2)
# (149292, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 67000 and from_word_group_id < 68000;
# ...query execution took: 2.44 seconds...
# (176396, 2)
# (293015, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 68000 and to_word_group_id < 69000;
# ...query execution took: 0.36 seconds...
# (127329, 2)
# (191301, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 68000 and from_word_group_id < 69000;
# ...query execution took: 2.73 seconds...
# (199229, 2)
# (337714, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 69000 and to_word_group_id < 70000;
# ...query execution took: 0.36 seconds...
# (125531, 2)
# (176712, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 69000 and from_word_group_id < 70000;
# ...query execution took: 3.04 seconds...
# (219447, 2)
# (371560, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 70000 and to_word_group_id < 71000;
# ...query execution took: 0.81 seconds...
# (290866, 2)
# (439207, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 70000 and from_word_group_id < 71000;
# ...query execution took: 2.15 seconds...
# (156995, 2)
# (262711, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 71000 and to_word_group_id < 72000;
# ...query execution took: 0.86 seconds...
# (291250, 2)
# (550240, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 71000 and from_word_group_id < 72000;
# ...query execution took: 5.88 seconds...
# (404772, 2)
# (705073, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 72000 and to_word_group_id < 73000;
# ...query execution took: 1.1 seconds...
# (384371, 2)
# (581724, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 72000 and from_word_group_id < 73000;
# ...query execution took: 4.0 seconds...
# (265719, 2)
# (484924, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 73000 and to_word_group_id < 74000;
# ...query execution took: 1.36 seconds...
# (472102, 2)
# (726040, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 73000 and from_word_group_id < 74000;
# ...query execution took: 2.93 seconds...
# (211118, 2)
# (359147, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 74000 and to_word_group_id < 75000;
# ...query execution took: 0.98 seconds...
# (361380, 2)
# (589961, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 74000 and from_word_group_id < 75000;
# ...query execution took: 2.47 seconds...
# (177311, 2)
# (301189, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 75000 and to_word_group_id < 76000;
# ...query execution took: 0.58 seconds...
# (208998, 2)
# (313658, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 75000 and from_word_group_id < 76000;
# ...query execution took: 3.51 seconds...
# (246575, 2)
# (466687, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 76000 and to_word_group_id < 77000;
# ...query execution took: 0.68 seconds...
# (253668, 2)
# (344819, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 76000 and from_word_group_id < 77000;
# ...query execution took: 2.51 seconds...
# (177433, 2)
# (289175, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 77000 and to_word_group_id < 78000;
# ...query execution took: 1.32 seconds...
# (465539, 2)
# (698004, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 77000 and from_word_group_id < 78000;
# ...query execution took: 3.13 seconds...
# (214046, 2)
# (371107, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 78000 and to_word_group_id < 79000;
# ...query execution took: 0.97 seconds...
# (357140, 2)
# (648998, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 78000 and from_word_group_id < 79000;
# ...query execution took: 2.69 seconds...
# (192060, 2)
# (352455, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 79000 and to_word_group_id < 80000;
# ...query execution took: 0.66 seconds...
# (232603, 2)
# (311229, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 79000 and from_word_group_id < 80000;
# ...query execution took: 6.98 seconds...
# (457950, 2)
# (742310, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 80000 and to_word_group_id < 81000;
# ...query execution took: 0.62 seconds...
# (223952, 2)
# (408351, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 80000 and from_word_group_id < 81000;
# ...query execution took: 6.69 seconds...
# (448475, 2)
# (781204, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 81000 and to_word_group_id < 82000;
# ...query execution took: 1.71 seconds...
# (600204, 2)
# (907854, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 81000 and from_word_group_id < 82000;
# ...query execution took: 3.73 seconds...
# (255741, 2)
# (414363, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 82000 and to_word_group_id < 83000;
# ...query execution took: 0.81 seconds...
# (291612, 2)
# (432985, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 82000 and from_word_group_id < 83000;
# ...query execution took: 3.51 seconds...
# (245640, 2)
# (403253, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 83000 and to_word_group_id < 84000;
# ...query execution took: 0.87 seconds...
# (322464, 2)
# (451772, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 83000 and from_word_group_id < 84000;
# ...query execution took: 3.74 seconds...
# (257124, 2)
# (414046, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 84000 and to_word_group_id < 85000;
# ...query execution took: 0.19 seconds...
# (69198, 2)
# (72419, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 84000 and from_word_group_id < 85000;
# ...query execution took: 11.26 seconds...
# (756370, 2)
# (1165559, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 85000 and to_word_group_id < 86000;
# ...query execution took: 1.04 seconds...
# (379772, 2)
# (431442, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 85000 and from_word_group_id < 86000;
# ...query execution took: 8.22 seconds...
# (517277, 2)
# (799647, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 86000 and to_word_group_id < 87000;
# ...query execution took: 1.5 seconds...
# (531036, 2)
# (746993, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 86000 and from_word_group_id < 87000;
# ...query execution took: 3.58 seconds...
# (250874, 2)
# (432266, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 87000 and to_word_group_id < 88000;
# ...query execution took: 0.73 seconds...
# (256412, 2)
# (417108, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 87000 and from_word_group_id < 88000;
# ...query execution took: 6.91 seconds...
# (461106, 2)
# (798817, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 88000 and to_word_group_id < 89000;
# ...query execution took: 0.35 seconds...
# (130855, 2)
# (170391, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 88000 and from_word_group_id < 89000;
# ...query execution took: 8.24 seconds...
# (566800, 2)
# (917878, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 89000 and to_word_group_id < 90000;
# ...query execution took: 0.76 seconds...
# (275972, 2)
# (498225, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 89000 and from_word_group_id < 90000;
# ...query execution took: 4.23 seconds...
# (294925, 2)
# (493845, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 90000 and to_word_group_id < 91000;
# ...query execution took: 0.83 seconds...
# (295252, 2)
# (660032, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 90000 and from_word_group_id < 91000;
# ...query execution took: 6.67 seconds...
# (445501, 2)
# (787079, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 91000 and to_word_group_id < 92000;
# ...query execution took: 0.15 seconds...
# (56852, 2)
# (86070, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 91000 and from_word_group_id < 92000;
# ...query execution took: 10.89 seconds...
# (733866, 2)
# (1318795, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 92000 and to_word_group_id < 93000;
# ...query execution took: 1.49 seconds...
# (546666, 2)
# (927013, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 92000 and from_word_group_id < 93000;
# ...query execution took: 5.82 seconds...
# (398003, 2)
# (692667, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 93000 and to_word_group_id < 94000;
# ...query execution took: 1.49 seconds...
# (525700, 2)
# (1000721, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 93000 and from_word_group_id < 94000;
# ...query execution took: 5.08 seconds...
# (343368, 2)
# (582295, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 94000 and to_word_group_id < 95000;
# ...query execution took: 0.8 seconds...
# (295747, 2)
# (746776, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 94000 and from_word_group_id < 95000;
# ...query execution took: 1.02 seconds...
# (84413, 2)
# (143125, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 95000 and to_word_group_id < 96000;
# ...query execution took: 0.19 seconds...
# (73638, 2)
# (105257, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 95000 and from_word_group_id < 96000;
# ...query execution took: 1.71 seconds...
# (132420, 2)
# (212569, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 96000 and to_word_group_id < 97000;
# ...query execution took: 0.31 seconds...
# (121660, 2)
# (183029, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 96000 and from_word_group_id < 97000;
# ...query execution took: 2.01 seconds...
# (150278, 2)
# (256624, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 97000 and to_word_group_id < 98000;
# ...query execution took: 0.61 seconds...
# (232559, 2)
# (308596, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 97000 and from_word_group_id < 98000;
# ...query execution took: 1.99 seconds...
# (147981, 2)
# (248515, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 98000 and to_word_group_id < 99000;
# ...query execution took: 1.57 seconds...
# (577476, 2)
# (1077656, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 98000 and from_word_group_id < 99000;
# ...query execution took: 5.01 seconds...
# (345609, 2)
# (629755, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 99000 and to_word_group_id < 100000;
# ...query execution took: 1.78 seconds...
# (646504, 2)
# (1350004, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 99000 and from_word_group_id < 100000;
# ...query execution took: 3.84 seconds...
# (256097, 2)
# (476659, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 100000 and to_word_group_id < 101000;
# ...query execution took: 2.2 seconds...
# (783786, 2)
# (1350010, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 100000 and from_word_group_id < 101000;
# ...query execution took: 3.66 seconds...
# (253476, 2)
# (432467, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 101000 and to_word_group_id < 102000;
# ...query execution took: 2.01 seconds...
# (741535, 2)
# (1426314, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 101000 and from_word_group_id < 102000;
# ...query execution took: 3.15 seconds...
# (222751, 2)
# (383277, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 102000 and to_word_group_id < 103000;
# ...query execution took: 2.76 seconds...
# (972389, 2)
# (1596393, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 102000 and from_word_group_id < 103000;
# ...query execution took: 2.39 seconds...
# (172050, 2)
# (298240, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 103000 and to_word_group_id < 104000;
# ...query execution took: 0.75 seconds...
# (282678, 2)
# (374116, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 103000 and from_word_group_id < 104000;
# ...query execution took: 6.11 seconds...
# (409706, 2)
# (676992, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 104000 and to_word_group_id < 105000;
# ...query execution took: 1.02 seconds...
# (374125, 2)
# (686072, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 104000 and from_word_group_id < 105000;
# ...query execution took: 4.97 seconds...
# (322601, 2)
# (576849, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 105000 and to_word_group_id < 106000;
# ...query execution took: 1.09 seconds...
# (386491, 2)
# (728590, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 105000 and from_word_group_id < 106000;
# ...query execution took: 3.74 seconds...
# (248235, 2)
# (463756, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 106000 and to_word_group_id < 107000;
# ...query execution took: 0.74 seconds...
# (272818, 2)
# (387652, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 106000 and from_word_group_id < 107000;
# ...query execution took: 6.35 seconds...
# (438739, 2)
# (753986, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 107000 and to_word_group_id < 108000;
# ...query execution took: 0.95 seconds...
# (341370, 2)
# (615141, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 107000 and from_word_group_id < 108000;
# ...query execution took: 6.6 seconds...
# (428790, 2)
# (748951, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 108000 and to_word_group_id < 109000;
# ...query execution took: 0.62 seconds...
# (226112, 2)
# (372665, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 108000 and from_word_group_id < 109000;
# ...query execution took: 9.1 seconds...
# (591325, 2)
# (966076, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 109000 and to_word_group_id < 110000;
# ...query execution took: 0.92 seconds...
# (341609, 2)
# (485492, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 109000 and from_word_group_id < 110000;
# ...query execution took: 3.96 seconds...
# (264584, 2)
# (450637, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 110000 and to_word_group_id < 111000;
# ...query execution took: 1.07 seconds...
# (377506, 2)
# (559994, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 110000 and from_word_group_id < 111000;
# ...query execution took: 3.78 seconds...
# (255716, 2)
# (454663, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 111000 and to_word_group_id < 112000;
# ...query execution took: 0.5 seconds...
# (183369, 2)
# (274660, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 111000 and from_word_group_id < 112000;
# ...query execution took: 5.09 seconds...
# (336518, 2)
# (566177, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 112000 and to_word_group_id < 113000;
# ...query execution took: 1.64 seconds...
# (594500, 2)
# (832434, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 112000 and from_word_group_id < 113000;
# ...query execution took: 2.55 seconds...
# (175341, 2)
# (294584, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 113000 and to_word_group_id < 114000;
# ...query execution took: 0.65 seconds...
# (226725, 2)
# (342556, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 113000 and from_word_group_id < 114000;
# ...query execution took: 4.99 seconds...
# (323699, 2)
# (516282, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 114000 and to_word_group_id < 115000;
# ...query execution took: 1.3 seconds...
# (469258, 2)
# (680156, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 114000 and from_word_group_id < 115000;
# ...query execution took: 4.29 seconds...
# (286410, 2)
# (477219, 4)
# #### TO WORDS
# ...
# ...query execution took: 15.08 seconds...
# (779346, 2)
# (1225747, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 179000 and to_word_group_id < 180000;
# ...query execution took: 0.16 seconds...
# (46131, 2)
# (49672, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 179000 and from_word_group_id < 180000;
# ...query execution took: 16.51 seconds...
# (852544, 2)
# (1378192, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 180000 and to_word_group_id < 181000;
# ...query execution took: 0.36 seconds...
# (111406, 2)
# (127137, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 180000 and from_word_group_id < 181000;
# ...query execution took: 4.56 seconds...
# (246376, 2)
# (396844, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 181000 and to_word_group_id < 182000;
# ...query execution took: 1.25 seconds...
# (394358, 2)
# (443792, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 181000 and from_word_group_id < 182000;
# ...query execution took: 5.09 seconds...
# (275169, 2)
# (447901, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 182000 and to_word_group_id < 183000;
# ...query execution took: 2.18 seconds...
# (686286, 2)
# (841644, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 182000 and from_word_group_id < 183000;
# ...query execution took: 3.49 seconds...
# (189350, 2)
# (341042, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 183000 and to_word_group_id < 184000;
# ...query execution took: 1.33 seconds...
# (412667, 2)
# (470091, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 183000 and from_word_group_id < 184000;
# ...query execution took: 7.48 seconds...
# (381093, 2)
# (646928, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 184000 and to_word_group_id < 185000;
# ...query execution took: 0.79 seconds...
# (245024, 2)
# (309254, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 184000 and from_word_group_id < 185000;
# ...query execution took: 7.92 seconds...
# (398697, 2)
# (696773, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 185000 and to_word_group_id < 186000;
# ...query execution took: 0.67 seconds...
# (204653, 2)
# (227879, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 185000 and from_word_group_id < 186000;
# ...query execution took: 8.39 seconds...
# (505677, 2)
# (819684, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 186000 and to_word_group_id < 187000;
# ...query execution took: 1.35 seconds...
# (553017, 2)
# (618676, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 186000 and from_word_group_id < 187000;
# ...query execution took: 3.34 seconds...
# (234324, 2)
# (382447, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 187000 and to_word_group_id < 188000;
# ...query execution took: 1.62 seconds...
# (682283, 2)
# (796669, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 187000 and from_word_group_id < 188000;
# ...query execution took: 2.43 seconds...
# (171327, 2)
# (290729, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 188000 and to_word_group_id < 189000;
# ...query execution took: 0.28 seconds...
# (112021, 2)
# (130321, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 188000 and from_word_group_id < 189000;
# ...query execution took: 8.51 seconds...
# (574934, 2)
# (992591, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 189000 and to_word_group_id < 190000;
# ...query execution took: 0.63 seconds...
# (250211, 2)
# (273597, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 189000 and from_word_group_id < 190000;
# ...query execution took: 5.91 seconds...
# (409901, 2)
# (696729, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 190000 and to_word_group_id < 191000;
# ...query execution took: 0.81 seconds...
# (342219, 2)
# (365247, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 190000 and from_word_group_id < 191000;
# ...query execution took: 4.69 seconds...
# (321915, 2)
# (539474, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 191000 and to_word_group_id < 192000;
# ...query execution took: 1.04 seconds...
# (422790, 2)
# (533215, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 191000 and from_word_group_id < 192000;
# ...query execution took: 3.16 seconds...
# (232339, 2)
# (376782, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 192000 and to_word_group_id < 193000;
# ...query execution took: 1.04 seconds...
# (410535, 2)
# (452861, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 192000 and from_word_group_id < 193000;
# ...query execution took: 9.28 seconds...
# (503437, 2)
# (801131, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 193000 and to_word_group_id < 194000;
# ...query execution took: 0.18 seconds...
# (54782, 2)
# (57787, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 193000 and from_word_group_id < 194000;
# ...query execution took: 7.94 seconds...
# (412128, 2)
# (667749, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 194000 and to_word_group_id < 195000;
# ...query execution took: 0.3 seconds...
# (89318, 2)
# (98618, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 194000 and from_word_group_id < 195000;
# ...query execution took: 8.87 seconds...
# (451333, 2)
# (707694, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 195000 and to_word_group_id < 196000;
# ...query execution took: 0.15 seconds...
# (42256, 2)
# (44706, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 195000 and from_word_group_id < 196000;
# ...query execution took: 11.19 seconds...
# (582886, 2)
# (918291, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 196000 and to_word_group_id < 197000;
# ...query execution took: 0.1 seconds...
# (30133, 2)
# (36997, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 196000 and from_word_group_id < 197000;
# ...query execution took: 8.65 seconds...
# (457696, 2)
# (775984, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 197000 and to_word_group_id < 198000;
# ...query execution took: 0.21 seconds...
# (61044, 2)
# (70533, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 197000 and from_word_group_id < 198000;
# ...query execution took: 9.5 seconds...
# (466623, 2)
# (743289, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 198000 and to_word_group_id < 199000;
# ...query execution took: 0.12 seconds...
# (37466, 2)
# (41423, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 198000 and from_word_group_id < 199000;
# ...query execution took: 6.54 seconds...
# (343511, 2)
# (542816, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 199000 and to_word_group_id < 200000;
# ...query execution took: 0.24 seconds...
# (69952, 2)
# (76283, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 199000 and from_word_group_id < 200000;
# ...query execution took: 6.14 seconds...
# (369656, 2)
# (598368, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 200000 and to_word_group_id < 201000;
# ...query execution took: 0.37 seconds...
# (148109, 2)
# (167565, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 200000 and from_word_group_id < 201000;
# ...query execution took: 4.65 seconds...
# (324142, 2)
# (529089, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 201000 and to_word_group_id < 202000;
# ...query execution took: 0.23 seconds...
# (95166, 2)
# (111243, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 201000 and from_word_group_id < 202000;
# ...query execution took: 6.77 seconds...
# (455117, 2)
# (733720, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 202000 and to_word_group_id < 203000;
# ...query execution took: 0.12 seconds...
# (46430, 2)
# (48441, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 202000 and from_word_group_id < 203000;
# ...query execution took: 8.06 seconds...
# (525024, 2)
# (834612, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 203000 and to_word_group_id < 204000;
# ...query execution took: 0.2 seconds...
# (82033, 2)
# (91237, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 203000 and from_word_group_id < 204000;
# ...query execution took: 6.96 seconds...
# (465501, 2)
# (765968, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 204000 and to_word_group_id < 205000;
# ...query execution took: 0.23 seconds...
# (93758, 2)
# (105620, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 204000 and from_word_group_id < 205000;
# ...query execution took: 4.89 seconds...
# (336267, 2)
# (541626, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 205000 and to_word_group_id < 206000;
# ...query execution took: 0.17 seconds...
# (62851, 2)
# (65635, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 205000 and from_word_group_id < 206000;
# ...query execution took: 5.96 seconds...
# (399373, 2)
# (653044, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 206000 and to_word_group_id < 207000;
# ...query execution took: 0.59 seconds...
# (233741, 2)
# (242541, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 206000 and from_word_group_id < 207000;
# ...query execution took: 3.39 seconds...
# (204483, 2)
# (327180, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 207000 and to_word_group_id < 208000;
# ...query execution took: 1.12 seconds...
# (343604, 2)
# (392048, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 207000 and from_word_group_id < 208000;
# ...query execution took: 5.46 seconds...
# (292136, 2)
# (473517, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 208000 and to_word_group_id < 209000;
# ...query execution took: 0.47 seconds...
# (151037, 2)
# (177241, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 208000 and from_word_group_id < 209000;
# ...query execution took: 5.17 seconds...
# (269192, 2)
# (457806, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 209000 and to_word_group_id < 210000;
# ...query execution took: 0.58 seconds...
# (186441, 2)
# (205925, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 209000 and from_word_group_id < 210000;
# ...query execution took: 4.18 seconds...
# (227997, 2)
# (376639, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 210000 and to_word_group_id < 211000;
# ...query execution took: 0.4 seconds...
# (125385, 2)
# (145114, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 210000 and from_word_group_id < 211000;
# ...query execution took: 2.89 seconds...
# (162217, 2)
# (269258, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 211000 and to_word_group_id < 212000;
# ...query execution took: 0.24 seconds...
# (72629, 2)
# (90898, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 211000 and from_word_group_id < 212000;
# ...query execution took: 2.57 seconds...
# (151093, 2)
# (264813, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 212000 and to_word_group_id < 213000;
# ...query execution took: 0.18 seconds...
# (52503, 2)
# (56624, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 212000 and from_word_group_id < 213000;
# ...query execution took: 1.92 seconds...
# (120713, 2)
# (195747, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 213000 and to_word_group_id < 214000;
# ...query execution took: 0.21 seconds...
# (63037, 2)
# (67118, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 213000 and from_word_group_id < 214000;
# ...query execution took: 2.6 seconds...
# (152107, 2)
# (252203, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 214000 and to_word_group_id < 215000;
# ...query execution took: 1.83 seconds...
# (592398, 2)
# (641812, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 214000 and from_word_group_id < 215000;
# ...query execution took: 2.86 seconds...
# (153165, 2)
# (245793, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 215000 and to_word_group_id < 216000;
# ...query execution took: 0.33 seconds...
# (107658, 2)
# (109791, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 215000 and from_word_group_id < 216000;
# ...query execution took: 2.85 seconds...
# (152192, 2)
# (234878, 4)
# #### TO WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where to_word_group_id >= 216000 and to_word_group_id < 217000;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 4)
# #### FROM WORDS
# select from_word_group_id, to_word_group_id from anagram_groups where from_word_group_id >= 216000 and from_word_group_id < 217000;
# ...query execution took: 0.0 seconds...
# (0, 2)
# (0, 4)

# %%
wg_df.head()
# Out:
# Empty DataFrame
# Columns: [from_word_group_id, to_word_group_id, from_word_id, to_word_id]
# Index: []

# %%
# select the list of words
sql = 'select * from words;'
word_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
# Out:
# ...query execution took: 1.65 seconds...

# %%
word_df.head()
# Out:
#     word  lcase  n_chars first_letter  word_id  word_group_id letter_group  \
# 0      A      a        1            a        0              0            a
# 1     aa     aa        2            a        1              1            a
# 2    aal    aal        3            a        2              2           al
# 3  aalii  aalii        5            a        3              3          ail
# 4    aam    aam        3            a        4              4           am
#
#   letter_group_ranked
# 0                   a
# 1                   a
# 2                  la
# 3                 lai
# 4                  ma

# %%
word_df['n_from_words'] = word_df['word_id'].map(from_word_counter)
word_df['n_to_words'] = word_df['word_id'].map(to_word_counter)

# %%
word_df.shape
# Out:
# (234370, 10)

# %%
# add in the counts of from_word_group_id and to_word_group_id
# the columns in words_me_0* are all the same
sql = 'select word_group_id, n_from_word_groups, n_to_word_groups from words_me_05;'
word_group_df = query_db(sql = sql, db_path=rc.db_path, db_name=rc.db_name)
# Out:
# ...query execution took: 0.74 seconds...

# %%
output_df = pd.merge(left = word_df, right = word_group_df)

# %%
output_df.shape
# Out:
# (234370, 12)

# %%
# sum of parent/child word relationships
output_df['n_from_words'].sum()
# Out:
# 123758418

# %%
# sum of parent/child word relationships
output_df['n_to_words'].sum()
# Out:
# 123758418

# %%
# sum of parent/child word group relationships: by from word groups
word_group_df['n_from_word_groups'].sum()
# Out:
# 73218235

# %%
# sum of parent/child word relationships: by to word groups
word_group_df['n_to_word_groups'].sum()
# Out:
# 73218235

# %%
# this is also the number of rows in the anagram group table

# %%
write_data_to_sqlite(df = output_df, table_name='word_counts', db_path=rc.db_path, db_name=rc.db_name)
# Out:
# ...now writing: word_counts
